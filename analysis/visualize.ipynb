# %%
import numpy as np
import pandas as pd
import os, json
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter
from visualize import plot_utility_fairness

# %%
df = pd.read_csv('ea_non-mm/ea_dp_or_eo_only_with_vanilla.csv')
df.shape
# Out:
# (275, 13)

# %%
plot_utility_fairness(df, dataset="pokec_z", backbone="gcn", lambda_param="lambda_dp")
plt.show()

# %%
plot_utility_fairness(df, dataset="pokec_z", backbone="gat", lambda_param="lambda_dp")
plt.show()

# %%
plot_utility_fairness(df, dataset="nba", backbone="gat", lambda_param="lambda_dp")
plt.show()

# %%
plot_utility_fairness(df, dataset="bail", backbone="sgc", lambda_param="lambda_eo")
plt.show()

# %%
del plot_utility_fairness
